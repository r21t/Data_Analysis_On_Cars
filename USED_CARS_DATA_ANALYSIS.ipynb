# %% [markdown]
# COLUMNS THAT ARE BEING REMOVED
# 1. url
# 2. region url
# 3. image url
# 4. countr --- it contains all null values and we can remove the column because the data is only from US.
# 5. VIN -- contains many null values in this column.
# 6. size - contains many null values in this column.

# %% [markdown]
# *  Lets first get a glimpse of what coulmns do we have
# * lets also see what are all the columns that we dotn need for the analysis and lest drop them.
#
# * we have 26 columns in total
# * We have 426880 total rows of data
# * first lets see how many null values does each column contain

# %% [markdown]
# * We are importing the data into data_frame variable
# *  have imported the pandas library

# %% [markdown]
# # EXPLORING THE DATA

# %%
import pandas as pd

data_frame = pd.read_csv(r"C:\Users\RaviTeja\Desktop\Learnings_Materials_Certifications\My Python\GIT_HUB_PULLED_PROJECTS\Data_Sets\vehicles.csv")

# %%
import pandas as pd

# %% [markdown]
# just getting the glimpse of the data

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
data_frame.describe()
# Out:
#                  id         price           year      odometer  county  \
# count  4.268800e+05  4.268800e+05  425675.000000  4.224800e+05     0.0
# mean   7.311487e+09  7.519903e+04    2011.235191  9.804333e+04     NaN
# std    4.473170e+06  1.218228e+07       9.452120  2.138815e+05     NaN
# min    7.207408e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.308143e+09  5.900000e+03    2008.000000  3.770400e+04     NaN
# 50%    7.312621e+09  1.395000e+04    2013.000000  8.554800e+04     NaN
# 75%    7.315254e+09  2.648575e+04    2017.000000  1.335425e+05     NaN
# max    7.317101e+09  3.736929e+09    2022.000000  1.000000e+07     NaN
#
#                  lat           long
# count  420331.000000  420331.000000
# mean       38.493940     -94.748599
# std         5.841533      18.365462
# min       -84.122245    -159.827728
# 25%        34.601900    -111.939847
# 50%        39.150100     -88.432600
# 75%        42.398900     -80.832039
# ...

# %% [markdown]
# lets see the percentage of null values in each column

# %%
data_frame.isna().sum().sort_values(ascending = False)
# Out:
# county          426880
# size            306361
# cylinders       177678
# condition       174104
# VIN             161042
# drive           130567
# paint_color     130203
# type             92858
# manufacturer     17646
# title_status      8242
# long              6549
# lat               6549
# model             5277
# odometer          4400
# fuel              3013
# transmission      2556
# year              1205
# description         70
# posting_date        68
# image_url           68
# state                0
# price                0
# region_url           0
# region               0
# url                  0
# id                   0
# dtype: int64

# %%
data_frame.isna().sum().sort_values(ascending = False) / len(data_frame)*100
# Out:
# county          100.000000
# size             71.767476
# cylinders        41.622470
# condition        40.785232
# VIN              37.725356
# drive            30.586347
# paint_color      30.501078
# type             21.752717
# manufacturer      4.133714
# title_status      1.930753
# long              1.534155
# lat               1.534155
# model             1.236179
# odometer          1.030735
# fuel              0.705819
# transmission      0.598763
# year              0.282281
# description       0.016398
# posting_date      0.015930
# image_url         0.015930
# state             0.000000
# price             0.000000
# region_url        0.000000
# region            0.000000
# url               0.000000
# id                0.000000
# dtype: float64

# %% [markdown]
# # DATA CLEANING & FORMATTING

# %%
data_frame.pop('size')
data_frame.pop('VIN')
data_frame.pop('cylinders')
data_frame.pop('condition')
data_frame.pop('paint_color')
data_frame.pop('drive')
data_frame.pop('type')
data_frame.pop('county')
data_frame.pop('url')
data_frame.pop('image_url')
data_frame.pop('region_url')
# Out:
# 0           https://prescott.craigslist.org
# 1              https://fayar.craigslist.org
# 2               https://keys.craigslist.org
# 3          https://worcester.craigslist.org
# 4         https://greensboro.craigslist.org
#                         ...
# 426875       https://wyoming.craigslist.org
# 426876       https://wyoming.craigslist.org
# 426877       https://wyoming.craigslist.org
# 426878       https://wyoming.craigslist.org
# 426879       https://wyoming.craigslist.org
# Name: region_url, Length: 426880, dtype: object

# %%
data_frame.pop('description')
# Out:
# 27        Carvana is the safer way to buy a car During t...
# 28        Carvana is the safer way to buy a car During t...
# 29        Carvana is the safer way to buy a car During t...
# 30        Carvana is the safer way to buy a car During t...
# 31        2013 F-150 XLT V6 4 Door. Good condition. Leve...
#                                 ...
# 426875    Carvana is the safer way to buy a car During t...
# 426876    Carvana is the safer way to buy a car During t...
# 426877    Carvana is the safer way to buy a car During t...
# 426878    Carvana is the safer way to buy a car During t...
# 426879    Carvana is the safer way to buy a car During t...
# Name: description, Length: 357706, dtype: object

# %%
data_frame.pop('id')
data_frame.pop('title_status')
data_frame.pop('lat')
data_frame.pop('long')
# Out:
# 27       -85.480000
# 28       -85.480000
# 29       -85.480000
# 30       -85.480000
# 31       -85.518900
#             ...
# 426875   -84.445400
# 426876   -84.445400
# 426877   -84.411811
# 426878   -84.445400
# 426879   -84.411811
# Name: long, Length: 357706, dtype: float64

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   region        426880 non-null  object
#  2   price         426880 non-null  int64
#  3   year          425675 non-null  float64
#  4   manufacturer  409234 non-null  object
#  5   model         421603 non-null  object
#  6   fuel          423867 non-null  object
#  7   odometer      422480 non-null  float64
#  8   title_status  418638 non-null  object
#  9   transmission  424324 non-null  object
#  10  description   426810 non-null  object
#  11  state         426880 non-null  object
#  12  lat           420331 non-null  float64
#  13  long          420331 non-null  float64
#  14  posting_date  426812 non-null  object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 48.9+ MB

# %% [markdown]
# so the percentage of null values in manufacturer and , type are 4.1 and 1.2 percentages respectively as we can see from the exploratory part.
# we are droping all the null values since we have many rows of data.

# %%
data_frame = data_frame.dropna()

# %%
data_frame.isna().sum().sort_values(ascending = False) / len(data_frame)*100
# Out:
# posting_date    0.0
# long            0.0
# lat             0.0
# state           0.0
# transmission    0.0
# title_status    0.0
# odometer        0.0
# fuel            0.0
# model           0.0
# manufacturer    0.0
# year            0.0
# price           0.0
# region          0.0
# id              0.0
# dtype: float64

# %% [markdown]
# Now lets check the data types of all the columns that we have and do the changes if needed

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383487 entries, 27 to 426879
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            383487 non-null  int64
#  1   region        383487 non-null  object
#  2   price         383487 non-null  int64
#  3   year          383487 non-null  float64
#  4   manufacturer  383487 non-null  object
#  5   model         383487 non-null  object
#  6   fuel          383487 non-null  object
#  7   odometer      383487 non-null  float64
#  8   title_status  383487 non-null  object
#  9   transmission  383487 non-null  object
#  10  description   383487 non-null  object
#  11  state         383487 non-null  object
#  12  lat           383487 non-null  float64
#  13  long          383487 non-null  float64
#  14  posting_date  383487 non-null  object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 46.8+ MB

# %%
data_frame['posting_date']
# Out:
# 27        2021-05-04T12:31:18-0500
# 28        2021-05-04T12:31:08-0500
# 29        2021-05-04T12:31:25-0500
# 30        2021-05-04T10:41:31-0500
# 31        2021-05-03T14:02:03-0500
#                     ...
# 426875    2021-04-04T03:21:31-0600
# 426876    2021-04-04T03:21:29-0600
# 426877    2021-04-04T03:21:17-0600
# 426878    2021-04-04T03:21:11-0600
# 426879    2021-04-04T03:21:07-0600
# Name: posting_date, Length: 383487, dtype: object

# %%
data_frame['year']
# Out:
# 27        2014.0
# 28        2010.0
# 29        2020.0
# 30        2017.0
# 31        2013.0
#            ...
# 426875    2019.0
# 426876    2020.0
# 426877    2020.0
# 426878    2018.0
# 426879    2019.0
# Name: year, Length: 383487, dtype: float64

# %% [markdown]
# * "year" column marked as float -- changing that to int.
# * "posting_date" marked as object -- changing that to only date and getting the time to another column.
# * "odometer" is marked as float --- changing that to int.

# %% [markdown]
# * NOTE: Even after changing it to year we still will get the datatype as int64, but i am trying the datetime in pandas

# %% [markdown]
# * trying out how to change the data to year .

# %%
df = data_frame['year']

# %%
df = pd.to_datetime(df,format = '%Y')

# %%
df = pd.DatetimeIndex(df).year

# %%
print(df)
# Out:
# Int64Index([2014, 2010, 2020, 2017, 2013, 2012, 2016, 2019, 2016, 2011,
#             ...
#             2020, 2018, 2020, 2018, 2018, 2019, 2020, 2020, 2018, 2019],
#            dtype='int64', name='year', length=383487)

# %% [markdown]
# * Now we can try this in the main data_frame

# %%
data_frame['year'] = pd.to_datetime(data_frame['year'],format = '%Y')

# %%
data_frame['year']
# Out:
# 27       2014-01-01
# 28       2010-01-01
# 29       2020-01-01
# 30       2017-01-01
# 31       2013-01-01
#             ...
# 426875   2019-01-01
# 426876   2020-01-01
# 426877   2020-01-01
# 426878   2018-01-01
# 426879   2019-01-01
# Name: year, Length: 383487, dtype: datetime64[ns]

# %%
data_frame['year'] = pd.DatetimeIndex(data_frame['year']).year

# %%
data_frame['year']
# Out:
# 27        2014
# 28        2010
# 29        2020
# 30        2017
# 31        2013
#           ...
# 426875    2019
# 426876    2020
# 426877    2020
# 426878    2018
# 426879    2019
# Name: year, Length: 383487, dtype: int64

# %% [markdown]
# * Changing the posting_date to only date,day,year and removing the time from the column
# * NOTE: first trying it by copying the posting_date column to another variable.

# %%
df_1 = data_frame['posting_date']

# %%
print(df_1)
# Out:
# 27        2021-05-04T12:31:18-0500
# 28        2021-05-04T12:31:08-0500
# 29        2021-05-04T12:31:25-0500
# 30        2021-05-04T10:41:31-0500
# 31        2021-05-03T14:02:03-0500
#                     ...
# 426875    2021-04-04T03:21:31-0600
# 426876    2021-04-04T03:21:29-0600
# 426877    2021-04-04T03:21:17-0600
# 426878    2021-04-04T03:21:11-0600
# 426879    2021-04-04T03:21:07-0600
# Name: posting_date, Length: 383487, dtype: object

# %%
df_1 = pd.to_datetime(df_1,utc = True).dt.date #while running this without utc = True i was given an error and then used utc = True and it worked.

# %%
print(df_1)
# Out:
# 27        2021-05-04
# 28        2021-05-04
# 29        2021-05-04
# 30        2021-05-04
# 31        2021-05-03
#              ...
# 426875    2021-04-04
# 426876    2021-04-04
# 426877    2021-04-04
# 426878    2021-04-04
# 426879    2021-04-04
# Name: posting_date, Length: 383487, dtype: object

# %%
#now we can try it in the main dataframe

data_frame['posting_date'] = pd.to_datetime(data_frame['posting_date'],utc= True).dt.date

# %%
data_frame['posting_date'] # we have chaned the values to only date by removing the time values.
# Out:
# 27        2021-05-04
# 28        2021-05-04
# 29        2021-05-04
# 30        2021-05-04
# 31        2021-05-03
#              ...
# 426875    2021-04-04
# 426876    2021-04-04
# 426877    2021-04-04
# 426878    2021-04-04
# 426879    2021-04-04
# Name: posting_date, Length: 383487, dtype: object

# %% [markdown]
# ### Takeaway from the cleaning process.
# * Removed columns that contains more than 20% of null values in the dataset.
# * Dropped the null value rows in th remaninig columns.
# * changed the data_type of "year" from float to int.
# * removed the time from the "posting_date" column .

# %%
# remaining number of columns and rows in the data.
data_frame.shape

# we have 15 columns 
# we have 383487 rows
# Out:
# (383487, 15)

# %%
# SO after plotting a graph for the price we see that it contains zeros the highest.
# we can remove the data that contains price as "Zero"

# %%
zero_removal = data_frame[data_frame['price'] == 0].index
data_frame.drop(zero_removal , inplace = True)

# %%
# I have observed some model names to be same but differntiated due to some additional signs or valules.
# saving the data_frame into csv file 
# loading the data into sql to dig in more easily.
data_frame.to_csv(r'C:\Users\RaviTeja\Desktop\Learnings_Materials_Certifications\My Python\Jupyter_Notes\SQL_Pull.csv', index=False)

# %% [markdown]
# * after loading the data into the sql i still found some empty values
# * the reason maybe is because they are a empty strings and not NaN values.
# * now i am trying to replace the empty values throughtout the data_set with numpy.nan then use dropna again

# %%
import numpy as np
data_frame['region'].replace(' ', np.nan, inplace=True) # so i replaced all the whitespaces to nan and removed them

# %%
data_frame.isna().sum()
# Out:
# region          0
# price           0
# year            0
# manufacturer    0
# model           0
# fuel            0
# odometer        0
# transmission    0
# state           0
# posting_date    0
# dtype: int64

# %% [markdown]
# * currently ford has the highest postings compared to the rest.
# * so focusing on the ford.
# * in sql i dig deep and found that same model was given a different names
# * In ford we have highest postings for f-150

# %% [markdown]
# * there are still more f-150 with the name of f150 so changed that too in sql. using the below query.

# %% [markdown]
#  update practice..df1
#  set model = 'f-150'
#  where manufacturer = 'ford'
#  and model like 'f1%'

# %% [markdown]
# * there are still many different names for the models in the data but it is impossible to set them all right.
# * there are even some un-relevant data in the model column too.

# %% [markdown]
# * there are some other values that need to be removed from the data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * but they all are only single rows . so leaving them out for now.

# %% [markdown]
# # DATA ANALYSIS

# %%
manufac_count = data_frame.manufacturer.value_counts()

# %%
import matplotlib as my
manufac_count.head(5).plot(kind = 'bar',color='green')

# %% [markdown]
# * So ford is the highest manufacturer. lets do some deep dive into ford and see what we can get.

# %%
model_manufac_data = data_frame.model.value_counts()

# %%
model_manufac_data.head(10).plot(kind = 'bar') # this is before changing the f150 to f-150 in sql

# %%
price_data = data_frame.price.value_counts()

# %% [markdown]
# As we can see we have clearly missed a part of cleaning and i am sure we have many mroe that we did not clean
#
# there are so many zero values in the price section of the data

# %%
# This is kept just for the refernce 
# the new bar is below
price_data.head().plot(kind = "bar")

# %%
price_data.head().plot(kind = "bar")

# %%
price_data.tail().plot(kind = "bar")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ford_data = data_frame[(data_frame.manufacturer == 'ford')]
sns.barplot(x=ford_data.model.value_counts().head(10),y=ford_data.model.value_counts().head(10).index)

plt.xlabel('Number of models')
plt.ylabel(None)
plt.title('Highest listings from Manufacturer-FORD')
# Out:
# Text(0.5, 1.0, 'Highest listings from Manufacturer-FORD')

# %%
loca = data_frame.region.value_counts()

# %%
loca.head(15).plot(kind = 'bar')

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357706 entries, 27 to 426879
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   region        357706 non-null  object
#  1   price         357706 non-null  int64
#  2   year          357706 non-null  int64
#  3   manufacturer  357706 non-null  object
#  4   model         357706 non-null  object
#  5   fuel          357706 non-null  object
#  6   odometer      357706 non-null  float64
#  7   transmission  357706 non-null  object
#  8   state         357706 non-null  object
#  9   posting_date  357706 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 30.0+ MB

# %%
data_frame.to_csv(r'C:\Users\RaviTeja\Desktop\Learnings_Materials_Certifications\My Python\Jupyter_Notes\df1.csv', index=False)

# %%
import matplotlib as plt
sns.lineplot(x = data_frame.odometer.head(100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c7d640db1b4> in <module>
#       1 import matplotlib as plt
# ----> 2 sns.lineplot(x = data_frame.odometer.head(100))
#
# NameError: name 'sns' is not defined

# %% [markdown]
# * From the data we can even get in which year the car sales were high
# * We can also compare the price of f-150 from ford by which year they bought and what is the odo and the price they are quouting.
